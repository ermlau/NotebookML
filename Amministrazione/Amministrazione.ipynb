# %%
# import delle librerie
import pandas as pd
from sklearn import preprocessing
import numpy as np

# %%
# import dei dati , il separatore di default è la virgola ma in questo caso l'export
# di sql server inserisce il punto e virgola quindi usiamo sep = ';'
Amministrazioni = pd.read_csv('Amministrazioni.csv', sep = ';')
# importo solo la roba che mi serve
AttributiGruppi = pd.read_csv('AttributiGruppi.csv', sep = ';', usecols = ['IdTipoAttributo','IdGruppo','Ordine','Nome','IdStoreProcedure','DataSource','DataMember','necessario','Discriminante','Principale','IdSPverificaAttributo','Regex','IsEsteso'])

# %%
AttributiGruppi
# Out:
#      IdTipoAttributo  IdGruppo  Ordine             Nome  IdStoreProcedure  \
# 0                  1        30       1             albo               NaN
# 1                  1      1347       1             albo               1.0
# 2                  3        35       1  codAssCategoria              19.0
# 3                  3        36       1  codAssCategoria               NaN
# 4                  3        47       1  codAssCategoria               NaN
# ..               ...       ...     ...              ...               ...
# 911                5      1816       4     DataScadenza              -1.0
# 912                3      1816       5  TicketRichiesto              -1.0
# 913                3      1816       6         TicketSN              -1.0
# 914                1       758       1      codiceUnita              10.0
# 915                1      1818       1      codiceUnita             537.0
#
#         DataSource       DataMember  necessario  Discriminante  Principale  \
# ...

# %%
# ora che ho i dati che mi servono devo filtrare solo le righe che mi servono
indexNames = Amministrazioni[ (Amministrazioni['ConsoleRiferimento'] != 'ConsoleIntranet') & (Amministrazioni['esposizione'] == 0) ].index
Amministrazioni.drop(indexNames , inplace=True)

# %%
# Tolgo le colonne che non mi servono
Amministrazioni.drop(['Id','Descrizione','IdAmm','applicationsID','ordine','RichiedeProtocollo','dataCreazione','ConsoleRiferimento','esposizione'], axis=1, inplace=True)

# %%
Amministrazioni
# Out:
#       IdTipoAmm  IdGruppo  IdDominio  IdSpCercaGruppo  IdSpCercaDominio  \
# 5             2        62          1              3.0             544.0
# 7             2        83          1              7.0             544.0
# 9             2        65          1              7.0             544.0
# 13            2        85          1              7.0             544.0
# 14            2        62          1              3.0             544.0
# ...         ...       ...        ...              ...               ...
# 1550          2       375          1            538.0             544.0
# 1551          2       375          1            543.0             544.0
# 1552          2      1828          1              7.0             544.0
# 1553          2      1829          1              7.0             544.0
# 1555          2      1831          1              7.0             544.0
#
#       IdSpGetIstanzeUtente ParamCercaGruppo ParamCercaDominio  \
# ...

# %%
AttributiGruppi['Nome'].unique()
# Out:
# array(['albo', 'codAssCategoria', 'codFornitore', 'codFornitorePadre',
#        'codPatronato', 'codPatronatoUffZon', 'codiceUnita',
#        'userNamePadre', 'dataComunicazione', 'numeroIscrizioneAlbo',
#        'appID', 'codiceRegione', 'CodiceUnita', 'codiceUsl', 'SedeMinLav',
#        'CodiceEnte', 'CodiceANIA', 'CFServizioNA', 'CFServizio', 'cfCaf',
#        'Ufficio', 'UfficioCaf', 'UfficioNA', 'AreaAAS', 'codiceProvincia',
#        'LivelloDA16', 'codiceUnitaCE', 'CodiceUnitaINPS', 'codicePA',
#        'tipoConsultazione', 'PermessiDURC', 'Permessi', 'codiceSA',
#        'codiceSOA', 'CFConsSocCoop', 'CFSocCapoGruppo',
#        'ProvinciaComunicazione', 'TerritorioCarab', 'IspettLavCarab',
#        'PermessiCC', 'Specializzazione', 'DataScadenza',
#        'codiceAvvocatura', 'SettoreAvvocatura', 'codicePermessoAmm',
#        'userName', 'Ruolo', 'Abilitazioni', 'Struttura', 'struttura',
#        'ApplicazionePOM', 'TipoAmministratore', 'AreaFunzionale',
# ...

# %%
AttributiGruppi.head(3)
# Out:
#    IdTipoAttributo  IdGruppo  Ordine             Nome  IdStoreProcedure  \
# 0                1        30       1             albo               NaN
# 1                1      1347       1             albo               1.0
# 2                3        35       1  codAssCategoria              19.0
#
#   DataSource DataMember  necessario  Discriminante  Principale  \
# 0        NaN        NaN         0.0              1           0
# 1        NaN        NaN         0.0              1           0
# 2        NaN        NaN         0.0              1           1
#
#    IdSPverificaAttributo Regex  IsEsteso
# 0                   28.0   NaN       NaN
# 1                    NaN   NaN       NaN
# 2                   17.0   NaN       NaN

# %%
X = AttributiGruppi.select_dtypes(include=[object])
X.head(3)
# Out:
#               Nome DataSource DataMember Regex
# 0             albo        NaN        NaN   NaN
# 1             albo        NaN        NaN   NaN
# 2  codAssCategoria        NaN        NaN   NaN

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
# 1. INSTANTIATE
# encode labels with value between 0 and n_classes-1.
le = preprocessing.LabelEncoder()


# 2/3. FIT AND TRANSFORM
# use df.apply() to apply le.fit_transform to all columns
X_2 = X.apply(le.fit_transform)
#X_2.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Programmi\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     112         try:
# --> 113             res = _encode_python(values, uniques, encode)
#     114         except TypeError:
#
# D:\Programmi\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      60     if uniques is None:
# ---> 61         uniques = sorted(set(values))
#      62         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-0ca5245981c3> in <module>
#       6 # 2/3. FIT AND TRANSFORM
# ...

# %%
nome_encoder = preprocessing.OneHotEncoder() # creo encoder

tmp = nome_encoder.fit(AttributiGruppi[['Nome']]) # gli faccio leggere tutti i valori e preparare le conversioni
#tmp.categories_

#pd.set_option('display.max_columns', 10) #set per dataframe
#np.set_printoptions(threshold=np.inf) # set per numpy
#np.set_printoptions(threshold=6)

t = nome_encoder.transform(AttributiGruppi[['Nome']]).toarray() # faccio la conversione e la metto in t
# nome_encoder.categories_ # stampo le categorie create

#AttributiGruppi_df = pd.DataFrame(tmp.toarray())

#AttributiGruppi['Nome']= nome_encoder.fit_transform(AttributiGruppi['Nome'])
#AttributiGruppi

#AttributiGruppi = AttributiGruppi.join(enc_df)
# Out:
# [array(['ABILITAZ_CRST', 'APPLICAZIONE', 'AREA_CRST', ..., 'userDelegante',
#         'userName', 'userNamePadre'], dtype=object)]

# %%
nome_encoder.inverse_transform([t[0]]) # transformazione inversa, da array a valore
# Out:
# array([['albo']], dtype=object)

# %%
nome_encoder.transform([t[0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-6629cd8fa6d2> in <module>
# ----> 1 nome_encoder.transform([t[0]])
#
# D:\Programmi\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in transform(self, X)
#     426         check_is_fitted(self)
#     427         # validation of X happens in _check_X called by _transform
# --> 428         X_int, X_mask = self._transform(X, handle_unknown=self.handle_unknown)
#     429
#     430         n_samples, n_features = X_int.shape
#
# D:\Programmi\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in _transform(self, X, handle_unknown)
#     106
#     107         if n_features != len(self.categories_):
# --> 108             raise ValueError(
#     109                 "The number of features in X is different to the number of "
# ...

# %%
type(t)
# Out:
# numpy.ndarray

# %%
convertire i dati alfanumerici in numerici
AttributiGruppi , Nome DataSource DataMember
Amministrazioni , ParamFiltroAttributo
